# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from collections import OrderedDict
import warnings

# %%
train_ds = np.loadtxt('../assets/training_dataset.txt', dtype=float)
test_ds = np.loadtxt('../assets/test_dataset.txt', dtype=float)
hidden_weight = np.loadtxt('../assets/hidden_weights.txt')
EPOCHS = 800
#suppress warnings
warnings.filterwarnings('ignore')

# %%
def data_extract(train_data):
    data_list = list()
    label_list = list()
    for val in train_data:
        data_list.append(val[0:784])
        label_list.append(int(val[784]))
    data_list = np.array(data_list)
    label_list = np.array(label_list)
    return data_list, label_list

np.random.shuffle(train_ds)

x_train, y_train = data_extract(train_ds)
x_test, y_test = data_extract(test_ds)
# x_train = x_train / 255

# %%
y_train
# Out:
# array([9, 6, 0, ..., 1, 0, 5])

# %%
class NeuralNetwork():
    
    def __init__(self, input_nn: int, output_nn: int, hidden_nn: list, hidden_layers: int, learning_rate=0.01, alpha=0.5, epochs=EPOCHS, high=0.75, low=0.25):
        self.input_nn = input_nn
        self.output_nn = output_nn
        self.hidden_nn = hidden_nn
        self.hidden_layers = hidden_layers
        self.learning_rate = learning_rate
        self.alpha = alpha
        self.epochs = epochs
        self.high = high
        self.low = low
        # self.b = np.array([np.random.uniform(-0.5, 0.5, None) for _ in range(self.hidden_nn[0])])
        self.b1 = np.array([np.random.uniform(-0.5, 0.5, None) for _ in range(self.hidden_nn[0])]) 
        self.y_hat = OrderedDict()
        # self.w1 = np.random.randn(self.hidden_nn[0], self.input_nn) * np.sqrt(1 / (self.input_nn + self.hidden_nn[0]))
        self.w1 = hidden_weight
        if hidden_layers < 2:
            self.w2 = np.random.randn(self.output_nn, self.hidden_nn[0]) * np.sqrt(1 / (self.output_nn + self.hidden_nn[0]))
            self.b2 = np.array([np.random.uniform(-0.5, 0.5, None) for _ in range(self.output_nn)])
        else:
            # add more bias for other layers
            self.w_dict = dict()
            self.b_dict = dict()
            for i in range(self.hidden_layers):
                temp = 'w' + str(i + 2)
                b_temp = 'b' + str(i + 2)
                if self.hidden_layers - i == 1:
                    self.w_dict[temp] = np.random.randn(self.output_nn, self.hidden_nn[i]) * np.sqrt(1 / (self.output_nn + self.hidden_nn[i]))
                    self.b_dict[b_temp] = np.array([np.random.uniform(-0.5, 0.5, None) for _ in range(self.output_nn)])
                    break
                self.w_dict[temp] = np.random.randn(self.hidden_nn[i + 1], self.hidden_nn[i]) * np.sqrt(1 / (self.hidden_nn[i + 1] + self.hidden_nn[i]))
                self.b_dict[b_temp] = np.array([np.random.uniform(-0.5, 0.5, None) for _ in range(self.hidden_nn[i])])
    
        
    def get_weight(self):
        if self.hidden_layers >= 2:
            return self.w1, self.w_dict
        return self.w1, self.w2
    
    
    def sigmoid(self, x):
        # if -x > np.log(np.finfo(type(x)).max):
        #     return 0.0    
        return 1.0/(1.0 + np.exp(-x))


    def sigmoid_prime(self, x):
        return self.sigmoid(x) * (1 - self.sigmoid(x))

    
    def forward_prop(self, input_ds):
        self.z1 = np.dot(input_ds, self.w1.T) + self.b1
        self.y_hat1 = self.sigmoid(self.z1)
        if self.hidden_layers < 2:
            self.z2 = np.dot(self.y_hat1, self.w2.T) + self.b2 # net input 
            self.y_hat2 = self.sigmoid(self.z2) # activation function for the output layer.
        else:
            self.z2 = np.dot(self.y_hat1, self.w_dict['w2'].T) + self.b2 # net input 
            self.y_hat['y_hat2'] = self.sigmoid(self.z2)
            for i in range(1, self.hidden_layers):
                temp_y = 'y_hat' + str(i + 1)
                temp_w = 'w' + str(i + 2)
                temp_b = 'b' + str(i + 2)
                z = np.dot(self.y_hat[temp_y], self.w_dict[temp_w].T) + self.b_dict[temp_b]
                temp_y = 'y_hat' + str(i + 2)
                self.y_hat[temp_y] = self.sigmoid(z)
                

    def get_output(self):
        if self.hidden_layers < 2:
            return self.y_hat2
        else:
            self.y_hat_val = list(self.y_hat.items())
            self.y_hat_value = np.array(list(self.y_hat_val[len(self.y_hat_val) - 1]))
            return np.asarray(self.y_hat_value[1])            
        
        
    def backward_prop(self, input_ds, y, epochs):
        
        m, n = input_ds.shape
          
        if self.hidden_layers < 2:
            self.theta(self.y_hat2)
            self.output_errors = y - self.y_hat2
            
            self.d_output = self.output_errors * self.sigmoid_prime(self.y_hat2)
            # print(self.d_output.shape)
            # print(self.w2.shape)
            # print(self.y_hat1.shape)
            # temp = np.dot(self.d_output, self.w2)
            # print(temp.shape)
            self.d_hidden = self.sigmoid_prime(self.y_hat1) * np.dot(self.d_output, self.w2)
            # print(self.y_hat1.shape)
            deltaw2 = self.learning_rate * np.dot(self.y_hat1.T, self.d_output) # Weights change for the second layer (hidden - output)           
            deltaw1 = self.learning_rate * np.dot(input_ds.T, self.d_hidden) # Weights change for the first layer (input - hidden)

            # delta_b1 = 0
            # delta_b2 = 0
            
            delta_b1 = 1 / m * np.sum(self.d_hidden) * self.learning_rate
            delta_b2 = 1 / m * np.sum(self.output_errors) * self.learning_rate
            
            if epochs > 1: #run after epoch = 1 
                deltaw2 += (self.alpha * self.pre_deltaw2) 
                deltaw1 += (self.alpha * self.pre_deltaw1)
                delta_b2 += (self.alpha * self.pre_delta_b2)
                delta_b1 += (self.alpha * self.pre_delta_b1)
                self.w2 += deltaw2.T # for (hidden - output)
                self.w1 += deltaw1.T # for (input - hidden)
                self.b1 += delta_b1
                self.b2 += delta_b2
            
            self.pre_deltaw2 = deltaw2 # update of weights change
            self.pre_deltaw1 = deltaw1 
            self.pre_delta_b2 = delta_b2 # update of bias change
            self.pre_delta_b1 = delta_b1
        
        else:
            
            w_key = ['w' + str(i + 2) for i in range(self.hidden_layers)]
            self.y_hat_val = list(self.y_hat.items())
            self.y_hat_value = np.array(list(self.y_hat_val[len(self.y_hat_val) - 1]))
            self.y_hat_val = np.array(list(self.y_hat_val))            
            self.theta(self.y_hat_value[1])            
            self.output_errors = y - self.y_hat_value[1]
            index = len(self.y_hat_val) - 1
            
            while (index >= 0):
                self.d_output = self.output_errors * self.sigmoid_prime(self.y_hat_val[index][1])
                self.d_hidden = self.sigmoid_prime(self.y_hat_val[index - 1][1]) * np.dot(self.d_output, self.w_dict[w_key[index]])

                deltaw2 = self.learning_rate * np.dot(np.transpose(self.y_hat_val[index - 1][1]), self.d_output) # Weights change for the second layer (hidden - output)
                deltaw1 = self.learning_rate * np.dot(np.transpose(input_ds), self.d_hidden) # Weights change for the first layer (input - hidden)

                if(epochs > 1): #run after epoch = 1 
                    deltaw2 += (self.alpha * self.pre_deltaw2) 
                    deltaw1 += (self.alpha * self.pre_deltaw1)
                    delta_b2 += (self.alpha * self.pre_delta_b2)
                    delta_b1 += (self.alpha * self.pre_delta_b1)
                    self.w2 += deltaw2.T # for (hidden - output)
                    self.w1 += deltaw1.T # for (input - output)
                    self.b1 += delta_b1
                    self.b2 += delta_b2
                
                self.pre_deltaw2 = deltaw2 # update of weights change
                self.pre_deltaw1 = deltaw1 
                self.pre_delta_b2 = delta_b2 # update of bias change
                self.pre_delta_b1 = delta_b1
                index -= 1
                self.theta(self.y_hat_val[index-1][1])               
                self.output_errors = self.y_hat_val[index][1] - self.y_hat_val[index-1][1]
        
        
    def theta(self, y_hat): # set theta for output values. Use during training.
        for q in y_hat:
            for idx, j in enumerate(q):
                if j >= self.high:
                    q[idx] = 1.0
                elif j <= self.low:
                    q[idx] = 0.0
        # for idx in range(len(y_hat)):
        #     if y_hat[idx] >= self.high:
        #         y_hat[idx] = 1.0
        #     elif y_hat[idx] <= self.low:
        #         y_hat[idx] = 0.0

# %%
def identify(y): # classify the output, get digit
    results = []
    for data in y:
        max_output = np.amax(data)
        count = 0
        for x in (data): 
            if x == max_output:
                results.append(count)
            count += 1
    return np.asarray(results)

def one_hot_encode(y): 
    one_hot_y = np.zeros((y.size, 10))
    one_hot_y[np.arange(y.size), y] = 1 
    out_hot_labels = one_hot_y.T
    return one_hot_y


def accuracy(y, yhat): 
    ERRORS = 0
    yhat_one = one_hot_encode(np.int_(identify(yhat)))
    for i in range(len(y)):
        for j in range(len(y[0])):
            if y[i][j] != yhat_one[i][j]:
                ERRORS += 1
                break
    return (ERRORS / len(y)) * 100

# %%
nn = NeuralNetwork(784, 10, [180], 1)
nn.forward_prop(x_train)
y_onehot = one_hot_encode(y_train)
y_test_onehot = one_hot_encode(y_test)
w1, w2 = nn.get_weight()
train_error_frac, test_error_frac = list(), list()

# %%
w1 # for testing to see in the weight did get train
# Out:
# array([[ 0.00615303,  0.03509156, -0.01830187, ..., -0.02930204,
#         -0.02751705,  0.01583924],
#        [ 0.00276875, -0.03903014, -0.02849899, ...,  0.01471919,
#          0.00547539, -0.04100142],
#        [ 0.04148321,  0.0194128 , -0.00305757, ..., -0.05565823,
#          0.0586446 ,  0.06678386],
#        ...,
#        [-0.00296191,  0.03365274, -0.03516757, ...,  0.02560871,
#          0.00375103,  0.02143028],
#        [ 0.07132253,  0.06153575, -0.08962715, ...,  0.04336144,
#         -0.00796287, -0.06970343],
#        [ 0.03858584,  0.05227889, -0.05092477, ..., -0.05409208,
#         -0.07112448,  0.0215019 ]])

# %%
for i in range(EPOCHS + 1):
    nn.forward_prop(x_train)
    if i % 10 == 0:
        print(f'Iteration {i}:')
        temp_train = accuracy(y_onehot, nn.get_output())
        train_error_frac.append(temp_train)
        print(f'Error fraction: {temp_train}')
    nn.backward_prop(x_train, y_onehot, i)
    if i % 10 == 0:
        nn.forward_prop(x_test)
        temp_test = accuracy(y_test_onehot, nn.get_output())
        test_error_frac.append(temp_test)
# Out:
# Iteration 0:
# Error fraction: 86.02499999999999
# Iteration 10:
# Error fraction: 19.325
# Iteration 20:
# Error fraction: 14.2
# Iteration 30:
# Error fraction: 11.899999999999999
# Iteration 40:
# Error fraction: 10.575
# Iteration 50:
# Error fraction: 9.65
# Iteration 60:
# Error fraction: 9.0
# Iteration 70:
# Error fraction: 8.6
# Iteration 80:
# Error fraction: 8.5
# Iteration 90:
# Error fraction: 8.25
# Iteration 100:
# Error fraction: 8.025
# Iteration 110:
# Error fraction: 7.8
# Iteration 120:
# Error fraction: 7.6
# Iteration 130:
# Error fraction: 7.575
# Iteration 140:
# Error fraction: 7.675
# Iteration 150:
# Error fraction: 7.725
# Iteration 160:
# Error fraction: 7.6
# Iteration 170:
# Error fraction: 7.6499999999999995
# Iteration 180:
# Error fraction: 7.675
# Iteration 190:
# Error fraction: 7.5
# Iteration 200:
# Error fraction: 7.375
# Iteration 210:
# Error fraction: 7.35
# Iteration 220:
# Error fraction: 7.2749999999999995
# Iteration 230:
# Error fraction: 7.225
# Iteration 240:
# Error fraction: 7.1499999999999995
# Iteration 250:
# Error fraction: 7.074999999999999
# Iteration 260:
# Error fraction: 7.025
# Iteration 270:
# Error fraction: 6.9750000000000005
# Iteration 280:
# Error fraction: 6.825
# Iteration 290:
# Error fraction: 6.9
# Iteration 300:
# Error fraction: 6.9
# Iteration 310:
# Error fraction: 6.950000000000001
# Iteration 320:
# Error fraction: 6.825
# Iteration 330:
# Error fraction: 6.8500000000000005
# Iteration 340:
# Error fraction: 6.8500000000000005
# Iteration 350:
# Error fraction: 7.025
# Iteration 360:
# Error fraction: 6.800000000000001
# Iteration 370:
# Error fraction: 6.800000000000001
# Iteration 380:
# Error fraction: 6.875000000000001
# Iteration 390:
# Error fraction: 6.950000000000001
# Iteration 400:
# Error fraction: 6.9750000000000005
# Iteration 410:
# Error fraction: 6.7
# Iteration 420:
# Error fraction: 6.625
# Iteration 430:
# Error fraction: 6.7250000000000005
# Iteration 440:
# Error fraction: 6.7250000000000005
# Iteration 450:
# Error fraction: 6.75
# Iteration 460:
# Error fraction: 6.65
# Iteration 470:
# Error fraction: 6.4750000000000005
# Iteration 480:
# Error fraction: 6.525
# Iteration 490:
# Error fraction: 6.45
# Iteration 500:
# Error fraction: 6.525
# Iteration 510:
# Error fraction: 6.575
# Iteration 520:
# Error fraction: 6.4
# Iteration 530:
# Error fraction: 6.5
# Iteration 540:
# Error fraction: 6.4
# Iteration 550:
# Error fraction: 6.3
# Iteration 560:
# Error fraction: 6.35
# Iteration 570:
# Error fraction: 6.25
# Iteration 580:
# Error fraction: 6.325
# Iteration 590:
# Error fraction: 6.35
# Iteration 600:
# Error fraction: 6.275
# Iteration 610:
# Error fraction: 6.225
# Iteration 620:
# Error fraction: 6.175
# Iteration 630:
# Error fraction: 6.2
# Iteration 640:
# Error fraction: 5.949999999999999
# Iteration 650:
# Error fraction: 6.0
# Iteration 660:
# Error fraction: 6.05
# Iteration 670:
# Error fraction: 6.0249999999999995
# Iteration 680:
# Error fraction: 6.1
# Iteration 690:
# Error fraction: 5.925
# Iteration 700:
# Error fraction: 5.825
# Iteration 710:
# Error fraction: 5.7
# Iteration 720:
# Error fraction: 5.8999999999999995
# Iteration 730:
# Error fraction: 5.925
# Iteration 740:
# Error fraction: 5.775
# Iteration 750:
# Error fraction: 5.875
# Iteration 760:
# Error fraction: 5.75
# Iteration 770:
# Error fraction: 5.7250000000000005
# Iteration 780:
# Error fraction: 5.75
# Iteration 790:
# Error fraction: 5.7250000000000005
# Iteration 800:
# Error fraction: 5.7

# %%
def index_output(y): 
    max_out = np.amax(y)
    counter = 0
    for x in y:
        if x == max_out:
            return counter
        counter += 1


def confusion_matrix(y, yhat):
    confuse = np.zeros((10, 10))
    for i, x in enumerate(y):
        y_output = int(index_output(x))
        yhat_output = int(index_output(yhat[i]))
        confuse[y_output][yhat_output] += 1
    return confuse

# %%
nn.forward_prop(x_train)
train_CM = confusion_matrix(y_onehot, one_hot_encode(np.int_(identify(nn.get_output()))))
train_frame = pd.DataFrame(train_CM)
train_frame.style.background_gradient('Greys').set_caption('TRAIN CONFUSION MATRIX').set_properties(**{'text-align': 'center', 
                        'padding': '12px', 
                        'width': '50px'}).set_table_styles([{'selector': 'th.col_heading', 
                         'props': 'text-align: center'},
                        {'selector': 'caption', 
                         'props': [('text-align', 'center'),
                                   ('font-size', '11pt'),
                                   ('font-weight', 'bold')]}])
# train_frame.dfi.export('../assets/train_confusematrix.png')
# Out:
# <style type="text/css">
# #T_f5f82 th.col_heading {
#   text-align: center;
# }
# #T_f5f82 caption {
#   text-align: center;
#   font-size: 11pt;
#   font-weight: bold;
# }
# #T_f5f82_row0_col0, #T_f5f82_row1_col1, #T_f5f82_row2_col2, #T_f5f82_row3_col3, #T_f5f82_row4_col4, #T_f5f82_row5_col5, #T_f5f82_row6_col6, #T_f5f82_row7_col7, #T_f5f82_row8_col8, #T_f5f82_row9_col9 {
#   background-color: #000000;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# #T_f5f82_row0_col1, #T_f5f82_row0_col2, #T_f5f82_row0_col3, #T_f5f82_row0_col4, #T_f5f82_row0_col5, #T_f5f82_row0_col6, #T_f5f82_row0_col7, #T_f5f82_row0_col8, #T_f5f82_row0_col9, #T_f5f82_row1_col0, #T_f5f82_row1_col2, #T_f5f82_row1_col3, #T_f5f82_row1_col4, #T_f5f82_row1_col5, #T_f5f82_row1_col6, #T_f5f82_row1_col7, #T_f5f82_row1_col8, #T_f5f82_row1_col9, #T_f5f82_row2_col0, #T_f5f82_row2_col1, #T_f5f82_row2_col3, #T_f5f82_row2_col4, #T_f5f82_row2_col5, #T_f5f82_row2_col6, #T_f5f82_row2_col9, #T_f5f82_row3_col0, #T_f5f82_row3_col1, #T_f5f82_row3_col4, #T_f5f82_row3_col6, #T_f5f82_row4_col0, #T_f5f82_row4_col1, #T_f5f82_row4_col2, #T_f5f82_row4_col3, #T_f5f82_row4_col5, #T_f5f82_row4_col7, #T_f5f82_row5_col0, #T_f5f82_row5_col1, #T_f5f82_row5_col2, #T_f5f82_row5_col4, #T_f5f82_row5_col7, #T_f5f82_row5_col9, #T_f5f82_row6_col0, #T_f5f82_row6_col1, #T_f5f82_row6_col2, #T_f5f82_row6_col3, #T_f5f82_row6_col5, #T_f5f82_row6_col7, #T_f5f82_row6_col8, #T_f5f82_row6_col9, #T_f5f82_row7_col0, #T_f5f82_row7_col1, #T_f5f82_row7_col2, #T_f5f82_row7_col3, #T_f5f82_row7_col5, #T_f5f82_row7_col6, #T_f5f82_row7_col8, #T_f5f82_row8_col0, #T_f5f82_row8_col1, #T_f5f82_row8_col2, #T_f5f82_row8_col4, #T_f5f82_row8_col6, #T_f5f82_row8_col7, #T_f5f82_row9_col0, #T_f5f82_row9_col1, #T_f5f82_row9_col2, #T_f5f82_row9_col5, #T_f5f82_row9_col6 {
#   background-color: #ffffff;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# #T_f5f82_row2_col7, #T_f5f82_row2_col8, #T_f5f82_row3_col2, #T_f5f82_row3_col9, #T_f5f82_row4_col6, #T_f5f82_row4_col8, #T_f5f82_row5_col6, #T_f5f82_row6_col4, #T_f5f82_row7_col4, #T_f5f82_row8_col3 {
#   background-color: #fefefe;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# #T_f5f82_row3_col5, #T_f5f82_row3_col7, #T_f5f82_row3_col8, #T_f5f82_row5_col3, #T_f5f82_row8_col5, #T_f5f82_row9_col3 {
#   background-color: #fdfdfd;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# #T_f5f82_row4_col9 {
#   background-color: #f8f8f8;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# #T_f5f82_row5_col8 {
#   background-color: #fbfbfb;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# #T_f5f82_row7_col9, #T_f5f82_row8_col9, #T_f5f82_row9_col7, #T_f5f82_row9_col8 {
#   background-color: #fcfcfc;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# #T_f5f82_row9_col4 {
#   background-color: #f9f9f9;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# </style>
# <table id="T_f5f82">
#   <caption>TRAIN CONFUSION MATRIX</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5f82_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f5f82_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_f5f82_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_f5f82_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_f5f82_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_f5f82_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_f5f82_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_f5f82_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_f5f82_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_f5f82_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5f82_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f5f82_row0_col0" class="data row0 col0" >396.000000</td>
#       <td id="T_f5f82_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_f5f82_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_f5f82_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_f5f82_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_f5f82_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_f5f82_row0_col6" class="data row0 col6" >2.000000</td>
#       <td id="T_f5f82_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_f5f82_row0_col8" class="data row0 col8" >1.000000</td>
#       <td id="T_f5f82_row0_col9" class="data row0 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f5f82_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f5f82_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_f5f82_row1_col1" class="data row1 col1" >398.000000</td>
#       <td id="T_f5f82_row1_col2" class="data row1 col2" >2.000000</td>
#       <td id="T_f5f82_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_f5f82_row1_col4" class="data row1 col4" >0.000000</td>
#       <td id="T_f5f82_row1_col5" class="data row1 col5" >0.000000</td>
#       <td id="T_f5f82_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_f5f82_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_f5f82_row1_col8" class="data row1 col8" >0.000000</td>
#       <td id="T_f5f82_row1_col9" class="data row1 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f5f82_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f5f82_row2_col0" class="data row2 col0" >3.000000</td>
#       <td id="T_f5f82_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_f5f82_row2_col2" class="data row2 col2" >385.000000</td>
#       <td id="T_f5f82_row2_col3" class="data row2 col3" >1.000000</td>
#       <td id="T_f5f82_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_f5f82_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_f5f82_row2_col6" class="data row2 col6" >2.000000</td>
#       <td id="T_f5f82_row2_col7" class="data row2 col7" >4.000000</td>
#       <td id="T_f5f82_row2_col8" class="data row2 col8" >5.000000</td>
#       <td id="T_f5f82_row2_col9" class="data row2 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f5f82_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f5f82_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_f5f82_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_f5f82_row3_col2" class="data row3 col2" >5.000000</td>
#       <td id="T_f5f82_row3_col3" class="data row3 col3" >369.000000</td>
#       <td id="T_f5f82_row3_col4" class="data row3 col4" >1.000000</td>
#       <td id="T_f5f82_row3_col5" class="data row3 col5" >7.000000</td>
#       <td id="T_f5f82_row3_col6" class="data row3 col6" >0.000000</td>
#       <td id="T_f5f82_row3_col7" class="data row3 col7" >7.000000</td>
#       <td id="T_f5f82_row3_col8" class="data row3 col8" >7.000000</td>
#       <td id="T_f5f82_row3_col9" class="data row3 col9" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f5f82_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f5f82_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_f5f82_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_f5f82_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_f5f82_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_f5f82_row4_col4" class="data row4 col4" >368.000000</td>
#       <td id="T_f5f82_row4_col5" class="data row4 col5" >1.000000</td>
#       <td id="T_f5f82_row4_col6" class="data row4 col6" >5.000000</td>
#       <td id="T_f5f82_row4_col7" class="data row4 col7" >1.000000</td>
#       <td id="T_f5f82_row4_col8" class="data row4 col8" >4.000000</td>
#       <td id="T_f5f82_row4_col9" class="data row4 col9" >20.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f5f82_level0_row5" class="row_heading

# %%
nn.forward_prop(x_test)
test_CM = confusion_matrix(y_test_onehot, one_hot_encode(np.int_(identify(nn.get_output()))))
test_frame = pd.DataFrame(test_CM)
test_frame.style.background_gradient('Greys').set_caption('TEST CONFUSION MATRIX').set_properties(**{'text-align': 'center', 
                        'padding': '12px', 
                        'width': '50px'}).set_table_styles([{'selector': 'th.col_heading', 
                         'props': 'text-align: center'},
                        {'selector': 'caption', 
                         'props': [('text-align', 'center'),
                                   ('font-size', '11pt'),
                                   ('font-weight', 'bold')]}])
# print(test_frame)
# test_frame.dfi.export('../assets/test_confusematrix.png')
# Out:
# <style type="text/css">
# #T_9c7b3 th.col_heading {
#   text-align: center;
# }
# #T_9c7b3 caption {
#   text-align: center;
#   font-size: 11pt;
#   font-weight: bold;
# }
# #T_9c7b3_row0_col0, #T_9c7b3_row1_col1, #T_9c7b3_row2_col2, #T_9c7b3_row3_col3, #T_9c7b3_row4_col4, #T_9c7b3_row5_col5, #T_9c7b3_row6_col6, #T_9c7b3_row7_col7, #T_9c7b3_row8_col8, #T_9c7b3_row9_col9 {
#   background-color: #000000;
#   color: #f1f1f1;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# #T_9c7b3_row0_col1, #T_9c7b3_row0_col3, #T_9c7b3_row0_col4, #T_9c7b3_row0_col5, #T_9c7b3_row0_col7, #T_9c7b3_row1_col0, #T_9c7b3_row1_col2, #T_9c7b3_row1_col6, #T_9c7b3_row1_col7, #T_9c7b3_row1_col9, #T_9c7b3_row2_col4, #T_9c7b3_row3_col0, #T_9c7b3_row3_col1, #T_9c7b3_row3_col4, #T_9c7b3_row4_col1, #T_9c7b3_row4_col5, #T_9c7b3_row4_col8, #T_9c7b3_row5_col1, #T_9c7b3_row5_col2, #T_9c7b3_row5_col7, #T_9c7b3_row5_col9, #T_9c7b3_row6_col0, #T_9c7b3_row6_col1, #T_9c7b3_row6_col3, #T_9c7b3_row6_col4, #T_9c7b3_row6_col7, #T_9c7b3_row6_col9, #T_9c7b3_row7_col0, #T_9c7b3_row7_col1, #T_9c7b3_row7_col2, #T_9c7b3_row7_col4, #T_9c7b3_row7_col6, #T_9c7b3_row9_col0, #T_9c7b3_row9_col1, #T_9c7b3_row9_col2, #T_9c7b3_row9_col3 {
#   background-color: #ffffff;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# #T_9c7b3_row0_col2, #T_9c7b3_row3_col8, #T_9c7b3_row5_col8, #T_9c7b3_row7_col3, #T_9c7b3_row8_col3, #T_9c7b3_row8_col9 {
#   background-color: #f9f9f9;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# #T_9c7b3_row0_col6, #T_9c7b3_row0_col8, #T_9c7b3_row0_col9, #T_9c7b3_row1_col3, #T_9c7b3_row1_col4, #T_9c7b3_row1_col5, #T_9c7b3_row1_col8, #T_9c7b3_row2_col0, #T_9c7b3_row2_col1, #T_9c7b3_row2_col5, #T_9c7b3_row2_col6, #T_9c7b3_row2_col9, #T_9c7b3_row3_col6, #T_9c7b3_row3_col9, #T_9c7b3_row4_col3, #T_9c7b3_row5_col0, #T_9c7b3_row5_col3, #T_9c7b3_row6_col5, #T_9c7b3_row7_col5, #T_9c7b3_row7_col8, #T_9c7b3_row8_col0, #T_9c7b3_row8_col1, #T_9c7b3_row8_col4, #T_9c7b3_row8_col7, #T_9c7b3_row9_col6, #T_9c7b3_row9_col8 {
#   background-color: #fefefe;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# #T_9c7b3_row2_col3, #T_9c7b3_row2_col8, #T_9c7b3_row3_col2, #T_9c7b3_row4_col7, #T_9c7b3_row5_col4, #T_9c7b3_row8_col2 {
#   background-color: #fbfbfb;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# #T_9c7b3_row2_col7, #T_9c7b3_row3_col5, #T_9c7b3_row9_col5 {
#   background-color: #fafafa;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# #T_9c7b3_row3_col7, #T_9c7b3_row4_col0, #T_9c7b3_row5_col6, #T_9c7b3_row8_col6 {
#   background-color: #fdfdfd;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# #T_9c7b3_row4_col2, #T_9c7b3_row6_col2, #T_9c7b3_row6_col8 {
#   background-color: #fcfcfc;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# #T_9c7b3_row4_col6, #T_9c7b3_row7_col9, #T_9c7b3_row8_col5 {
#   background-color: #f7f7f7;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# #T_9c7b3_row4_col9 {
#   background-color: #f4f4f4;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# #T_9c7b3_row9_col4 {
#   background-color: #f1f1f1;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# #T_9c7b3_row9_col7 {
#   background-color: #f2f2f2;
#   color: #000000;
#   text-align: center;
#   padding: 12px;
#   width: 50px;
# }
# </style>
# <table id="T_9c7b3">
#   <caption>TEST CONFUSION MATRIX</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c7b3_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_9c7b3_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_9c7b3_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_9c7b3_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_9c7b3_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_9c7b3_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_9c7b3_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_9c7b3_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_9c7b3_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_9c7b3_level0_col9" class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c7b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c7b3_row0_col0" class="data row0 col0" >93.000000</td>
#       <td id="T_9c7b3_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_9c7b3_row0_col2" class="data row0 col2" >4.000000</td>
#       <td id="T_9c7b3_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_9c7b3_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_9c7b3_row0_col5" class="data row0 col5" >0.000000</td>
#       <td id="T_9c7b3_row0_col6" class="data row0 col6" >1.000000</td>
#       <td id="T_9c7b3_row0_col7" class="data row0 col7" >0.000000</td>
#       <td id="T_9c7b3_row0_col8" class="data row0 col8" >1.000000</td>
#       <td id="T_9c7b3_row0_col9" class="data row0 col9" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c7b3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9c7b3_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_9c7b3_row1_col1" class="data row1 col1" >96.000000</td>
#       <td id="T_9c7b3_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_9c7b3_row1_col3" class="data row1 col3" >1.000000</td>
#       <td id="T_9c7b3_row1_col4" class="data row1 col4" >1.000000</td>
#       <td id="T_9c7b3_row1_col5" class="data row1 col5" >1.000000</td>
#       <td id="T_9c7b3_row1_col6" class="data row1 col6" >0.000000</td>
#       <td id="T_9c7b3_row1_col7" class="data row1 col7" >0.000000</td>
#       <td id="T_9c7b3_row1_col8" class="data row1 col8" >1.000000</td>
#       <td id="T_9c7b3_row1_col9" class="data row1 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c7b3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9c7b3_row2_col0" class="data row2 col0" >1.000000</td>
#       <td id="T_9c7b3_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_9c7b3_row2_col2" class="data row2 col2" >85.000000</td>
#       <td id="T_9c7b3_row2_col3" class="data row2 col3" >3.000000</td>
#       <td id="T_9c7b3_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_9c7b3_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_9c7b3_row2_col6" class="data row2 col6" >1.000000</td>
#       <td id="T_9c7b3_row2_col7" class="data row2 col7" >4.000000</td>
#       <td id="T_9c7b3_row2_col8" class="data row2 col8" >3.000000</td>
#       <td id="T_9c7b3_row2_col9" class="data row2 col9" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c7b3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9c7b3_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_9c7b3_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_9c7b3_row3_col2" class="data row3 col2" >3.000000</td>
#       <td id="T_9c7b3_row3_col3" class="data row3 col3" >85.000000</td>
#       <td id="T_9c7b3_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_9c7b3_row3_col5" class="data row3 col5" >4.000000</td>
#       <td id="T_9c7b3_row3_col6" class="data row3 col6" >1.000000</td>
#       <td id="T_9c7b3_row3_col7" class="data row3 col7" >2.000000</td>
#       <td id="T_9c7b3_row3_col8" class="data row3 col8" >4.000000</td>
#       <td id="T_9c7b3_row3_col9" class="data row3 col9" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c7b3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9c7b3_row4_col0" class="data row4 col0" >2.000000</td>
#       <td id="T_9c7b3_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_9c7b3_row4_col2" class="data row4 col2" >2.000000</td>
#       <td id="T_9c7b3_row4_col3" class="data row4 col3" >1.000000</td>
#       <td id="T_9c7b3_row4_col4" class="data row4 col4" >79.000000</td>
#       <td id="T_9c

# %%
nn.forward_prop(x_test)
print(accuracy(y_test_onehot, nn.get_output())) # check accuracy on test set
# Out:
# 13.700000000000001

# %%
fig, ax = plt.subplots(1, 1, sharex=True, figsize=(24, 14))
plt.style.use('ggplot')
fraction = [test_error_frac, train_error_frac]
graph_label = ['Test Error', 'Train Error']
for i, x in enumerate(fraction):
    plt.plot(x, label=graph_label[i])
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), prop={'size': 12})
plt.title('Training set and Test set error rate over time', fontsize=20)
plt.xlabel('Every 10 epochs', fontsize=18)
plt.ylabel('Error rate', fontsize=18)
fig.savefig('../assets/error_fraction.png')
